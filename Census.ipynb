# %%
# Importing the required Libraries
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px

# %%
df = pd.DataFrame()

# %%
# Import and Read file
df = pd.read_csv(r"C:\Users\HP\Desktop\DATA ANALYSIS\Quantum Analytics\DAFI Project\Python Projects\census.csv")
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %% [markdown]
# ## Data Inspection

# %%
# first 10 rows of data
df.head(10)
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME          CTYNAME  \
# 0      40       3         6      1       0  Alabama          Alabama
# 1      50       3         6      1       1  Alabama   Autauga County
# 2      50       3         6      1       3  Alabama   Baldwin County
# 3      50       3         6      1       5  Alabama   Barbour County
# 4      50       3         6      1       7  Alabama      Bibb County
# 5      50       3         6      1       9  Alabama    Blount County
# 6      50       3         6      1      11  Alabama   Bullock County
# 7      50       3         6      1      13  Alabama    Butler County
# 8      50       3         6      1      15  Alabama   Calhoun County
# 9      50       3         6      1      17  Alabama  Chambers County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# ...

# %%
# last 10 rows of data
df.tail(10)
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 3183      50       4         8     56      27  Wyoming    Niobrara County
# 3184      50       4         8     56      29  Wyoming        Park County
# 3185      50       4         8     56      31  Wyoming      Platte County
# 3186      50       4         8     56      33  Wyoming    Sheridan County
# 3187      50       4         8     56      35  Wyoming    Sublette County
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# 3183           2484               2484             2492  ...
# ...

# %%
# shape of the data
df.shape
# Out:
# (3193, 100)

# %%
# size of the data
df.size
# Out:
# 319300

# %%
# check the columns
df.columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
#        'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010',
#        'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
#        'POPESTIMATE2014', 'POPESTIMATE2015', 'NPOPCHG_2010', 'NPOPCHG_2011',
#        'NPOPCHG_2012', 'NPOPCHG_2013', 'NPOPCHG_2014', 'NPOPCHG_2015',
#        'BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012', 'BIRTHS2013', 'BIRTHS2014',
#        'BIRTHS2015', 'DEATHS2010', 'DEATHS2011', 'DEATHS2012', 'DEATHS2013',
#        'DEATHS2014', 'DEATHS2015', 'NATURALINC2010', 'NATURALINC2011',
#        'NATURALINC2012', 'NATURALINC2013', 'NATURALINC2014', 'NATURALINC2015',
#        'INTERNATIONALMIG2010', 'INTERNATIONALMIG2011', 'INTERNATIONALMIG2012',
#        'INTERNATIONALMIG2013', 'INTERNATIONALMIG2014', 'INTERNATIONALMIG2015',
#        'DOMESTICMIG2010', 'DOMESTICMIG2011', 'DOMESTICMIG2012',
#        'DOMESTICMIG2013', 'DOMESTICMIG2014', 'DOMESTICMIG2015', 'NETMIG2010',
# ...

# %%
df.columns.tolist()
# Out:
# ['SUMLEV',
#  'REGION',
#  'DIVISION',
#  'STATE',
#  'COUNTY',
#  'STNAME',
#  'CTYNAME',
#  'CENSUS2010POP',
#  'ESTIMATESBASE2010',
#  'POPESTIMATE2010',
#  'POPESTIMATE2011',
#  'POPESTIMATE2012',
#  'POPESTIMATE2013',
#  'POPESTIMATE2014',
#  'POPESTIMATE2015',
#  'NPOPCHG_2010',
#  'NPOPCHG_2011',
#  'NPOPCHG_2012',
#  'NPOPCHG_2013',
#  'NPOPCHG_2014',
#  'NPOPCHG_2015',
#  'BIRTHS2010',
#  'BIRTHS2011',
#  'BIRTHS2012',
#  'BIRTHS2013',
#  'BIRTHS2014',
#  'BIRTHS2015',
#  'DEATHS2010',
#  'DEATHS2011',
#  'DEATHS2012',
#  'DEATHS2013',
#  'DEATHS2014',
#  'DEATHS2015',
#  'NATURALINC2010',
#  'NATURALINC2011',
#  'NATURALINC2012',
#  'NATURALINC2013',
#  'NATURALINC2014',
#  'NATURALINC2015',
#  'INTERNATIONALMIG2010',
#  'INTERNATIONALMIG2011',
#  'INTERNATIONALMIG2012',
#  'INTERNATIONALMIG2013',
#  'INTERNATIONALMIG2014',
#  'INTERNATIONALMIG2015',
#  'DOMESTICMIG2010',
#  'DOMESTICMIG2011',
#  'DOMESTICMIG2012',
#  'DOMESTICMIG2013',
#  'DOMESTICMIG2014',
# ...

# %%
# check the data types
df.dtypes
# Out:
# SUMLEV           int64
# REGION           int64
# DIVISION         int64
# STATE            int64
# COUNTY           int64
#                 ...
# RNETMIG2011    float64
# RNETMIG2012    float64
# RNETMIG2013    float64
# RNETMIG2014    float64
# RNETMIG2015    float64
# Length: 100, dtype: object

# %%
# check the data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3193 entries, 0 to 3192
# Data columns (total 100 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SUMLEV                 3193 non-null   int64
#  1   REGION                 3193 non-null   int64
#  2   DIVISION               3193 non-null   int64
#  3   STATE                  3193 non-null   int64
#  4   COUNTY                 3193 non-null   int64
#  5   STNAME                 3193 non-null   object
#  6   CTYNAME                3193 non-null   object
#  7   CENSUS2010POP          3193 non-null   int64
#  8   ESTIMATESBASE2010      3193 non-null   int64
#  9   POPESTIMATE2010        3193 non-null   int64
#  10  POPESTIMATE2011        3193 non-null   int64
#  11  POPESTIMATE2012        3193 non-null   int64
#  12  POPESTIMATE2013        3193 non-null   int64
#  13  POPESTIMATE2014        3193 non-null   int64
#  14  POPESTIMATE2015        3193 non-null   int64
# ...

# %%
# Check for missing values
df.isnull()
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY  STNAME  CTYNAME  CENSUS2010POP  \
# 0      False   False     False  False   False   False    False          False
# 1      False   False     False  False   False   False    False          False
# 2      False   False     False  False   False   False    False          False
# 3      False   False     False  False   False   False    False          False
# 4      False   False     False  False   False   False    False          False
# ...      ...     ...       ...    ...     ...     ...      ...            ...
# 3188   False   False     False  False   False   False    False          False
# 3189   False   False     False  False   False   False    False          False
# 3190   False   False     False  False   False   False    False          False
# 3191   False   False     False  False   False   False    False          False
# 3192   False   False     False  False   False   False    False          False
#
# ...

# %%
df.isnull().sum()
# Out:
# SUMLEV         0
# REGION         0
# DIVISION       0
# STATE          0
# COUNTY         0
#               ..
# RNETMIG2011    0
# RNETMIG2012    0
# RNETMIG2013    0
# RNETMIG2014    0
# RNETMIG2015    0
# Length: 100, dtype: int64

# %% [markdown]
# ## Data Wrangling And Visualization

# %% [markdown]
# ### 1. Which state has the most countries in it?

# %%
# Count the number of countries in each state
county_counts = df.groupby('STNAME').size()
print(county_counts)
# Out:
# STNAME
# Alabama                  68
# Alaska                   30
# Arizona                  16
# Arkansas                 76
# California               59
# Colorado                 65
# Connecticut               9
# Delaware                  4
# District of Columbia      2
# Florida                  68
# Georgia                 160
# Hawaii                    6
# Idaho                    45
# Illinois                103
# Indiana                  93
# Iowa                    100
# Kansas                  106
# Kentucky                121
# Louisiana                65
# Maine                    17
# Maryland                 25
# Massachusetts            15
# Michigan                 84
# Minnesota                88
# Mississippi              83
# Missouri                116
# Montana                  57
# Nebraska                 94
# Nevada                   18
# New Hampshire            11
# New Jersey               22
# New Mexico               34
# New York                 63
# ...

# %%
# Maximum County
max_county = county_counts.max()
print(max_countries)
# Out:
# 255

# %%
# State with the highest count of countries
state_by_max_county = county_counts[county_counts == max_countries].index[0]
print(f'State with the most county is {state_by_max_countries} with {max_countries} countries.')
# Out:
# State with the most county is Texas with 255 countries.

# %%
# Assume 'df' is your DataFrame and 'STNAME' and 'COUNTY' are the columns for state names and number of countries respectively
# Group by state name and count the number of countries in each state
state_counts = df.groupby('STNAME')['COUNTY'].count()

# Sort the states by number of countries and take the top 10
top_10_states = state_counts.sort_values(ascending=False).head(10)

# Create a bar chart
plt.figure(figsize=(10,5))
plt.bar(top_10_states.index, top_10_states.values)

# Add title and labels
plt.title('Top 10 States with the Most County')
plt.xlabel('State')
plt.ylabel('Number of County')

# Display the plot
plt.show()

# %% [markdown]
# ### Key Insights
# Texas is the highest state with the most County with 255 County.

# %% [markdown]
# ### 2.  Only looking at the three most populous countries for each state, what are the three most populous states (in order of highest population to lowest population)?

# %%
# Convert the population column to integers
df['CENSUS2010POP'] = df['CENSUS2010POP'].astype(int)
df['CENSUS2010POP'].describe()
# Out:
# count    3.193000e+03
# mean     1.933871e+05
# std      1.176201e+06
# min      8.200000e+01
# 25%      1.129900e+04
# 50%      2.642400e+04
# 75%      7.140400e+04
# max      3.725396e+07
# Name: CENSUS2010POP, dtype: float64

# %%
# Group the data by state and sum the population for each state
populations = df.groupby('STNAME')['CENSUS2010POP'].sum()
populations
# Out:
# STNAME
# Alabama                  9559472
# Alaska                   1420462
# Arizona                 12784034
# Arkansas                 5831836
# California              74507912
# Colorado                10058392
# Connecticut              7148194
# Delaware                 1795868
# District of Columbia     1203446
# Florida                 37602620
# Georgia                 19375306
# Hawaii                   2720602
# Idaho                    3135164
# Illinois                25661264
# Indiana                 12967604
# Iowa                     6092710
# Kansas                   5706236
# Kentucky                 8678734
# Louisiana                9066744
# Maine                    2656722
# Maryland                11547104
# Massachusetts           13095258
# Michigan                19767280
# Minnesota               10607850
# Mississippi              5934594
# Missouri                11977854
# Montana                  1978830
# Nebraska                 3652682
# ...

# %%
# Sort the data by population in descending order
populations = populations.sort_values(ascending=False)
populations
# Out:
# STNAME
# California              74507912
# Texas                   50291122
# New York                38756204
# Florida                 37602620
# Illinois                25661264
# Pennsylvania            25404758
# Ohio                    23073008
# Michigan                19767280
# Georgia                 19375306
# North Carolina          19070966
# New Jersey              17583788
# Virginia                15995826
# Washington              13449080
# Massachusetts           13095258
# Indiana                 12967604
# Arizona                 12784034
# Tennessee               12692210
# Missouri                11977854
# Maryland                11547104
# Wisconsin               11373972
# Minnesota               10607850
# Colorado                10058392
# Alabama                  9559472
# South Carolina           9250728
# Louisiana                9066744
# Kentucky                 8678734
# Oregon                   7662148
# Oklahoma                 7502702
# ...

# %%
# Get the top 3 most populous states
top_3_states = populations.sort_values(ascending=False).head(3)
top_3_states
print(f'The Top 3 most populous states are: {top_3_states.index[0]} ({top_3_states[0]:,}), {top_3_states.index[1]} ({top_3_states[1]:,}), and {top_3_states.index[2]} ({top_3_states[2]:,}).')
# Out:
# The Top 3 most populous states are: California (74,507,912), Texas (50,291,122), and New York (38,756,204).

# %%
# Group by state name and sum the population in each state, then take the top 3
top_3_populations = df.groupby('STNAME')['CENSUS2010POP'].sum().nlargest(3)

# Create a horizontal bar chart
plt.figure(figsize=(10,5))
plt.barh(top_3_populations.index, top_3_populations.values)

# Add title and labels
plt.title('Top 3 States by Population')
plt.xlabel('Population')
plt.ylabel('State')

# Display the plot
plt.show()

# %%
# Count the number of counties in each city
country_counts_city = df.groupby('CTYNAME').size()
print(country_counts_city)
# Out:
# CTYNAME
# Abbeville County             1
# Acadia Parish                1
# Accomack County              1
# Ada County                   1
# Adair County                 4
#                             ..
# Yukon-Koyukuk Census Area    1
# Yuma County                  2
# Zapata County                1
# Zavala County                1
# Ziebach County               1
# Length: 1927, dtype: int64

# %%
import pandas as pd

# Assuming county_counts_city is a pandas Series containing the county numbers in a city
# Creating a sample pandas Series for demonstration purposes
county_counts_city = pd.Series([10, 20, 15, 30, 25])

# Finding the maximum county number in the city
max_counties_city = county_counts_city.max()
print("Maximum county number in the city:", max_counties_city)
# Out:
# Maximum county number in the city: 30

# %%
# Find the city with the maximum number of countries
city_with_max_countries = country_counts_city[country_counts_city == max_counties_city].index[0]
print(f'The City with the most Countries is {city_with_max_countries} with {max_counties_city} countries.')
# Out:
# The City with the most Countries is Washington County with 30 countries.

# %%
# Group by county name and count the number of cities in each county, then take the top 5
top_5_counties = df.groupby('CTYNAME').size().nlargest(5)

# Create a pie chart
plt.figure(figsize=(10,5))
plt.pie(top_5_counties.values, labels=top_5_counties.index, autopct=lambda p: '{:.1f}% ({:.0f})'.format(p, p * sum(top_5_counties.values) / 100))

# Add title
plt.title('Top 5 Counties with the Most Cities')

# Display the plot
plt.show()

# %% [markdown]
# ## Which region has the most division in it?

# %%
# Count the number of counties in each state
division_counts = df.groupby('REGION').size()
print(division_counts)
# Out:
# REGION
# 1     226
# 2    1067
# 3    1439
# 4     461
# dtype: int64

# %%
# Find the maximum division
max_division = division_counts.max()
print(max_division)
# Out:
# 1439

# %%
# Find the Region with the maximum number of divisions
region_with_max_division = division_counts[division_counts == max_division].index[0]
print(f'The region with the most divisions is Region {region_with_max_division} with {max_division} divisions.')
# Out:
# The region with the most divisions is Region 3 with 1439 divisions.

# %%
# Group by region and count the number of occurrences in each region
division_counts = df.groupby('REGION').size()

# Convert the index to string type
division_counts.index = division_counts.index.astype(str)

# Create a line chart
plt.figure(figsize=(10,5))
plt.plot(division_counts.index, division_counts.values)

# Add title and labels
plt.title('Regions by Divisions')
plt.xlabel('Region')
plt.ylabel('Count')

# Display the plot
plt.show()
